# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x1 = 2.0 / 10000
print(f"{x1:.18f}")
# Out:
# 0.000200000000000000

# %%
data = pd.read_csv("housing.csv")

# %%
x2 = 1 + (1/10000) - (1- 1/10000)
print(f"{x2:.18f}")
# Out:
# 0.000199999999999978

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

x = data.drop(['median_house_value'], axis=1)
y = data['median_house_value']

# %%
x
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income ocean_proximity
# 0           322.0       126.0         8.3252        NEAR BAY
# 1          2401.0      1138.0         8.3014        NEAR BAY
# 2           496.0       177.0         7.2574        NEAR BAY
# 3           558.0       219.0         5.6431        NEAR BAY
# 4           565.0       259.0         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635       845.0       330.0         1.5603          INLAND
# 20636       356.0       114.0         2.5568          INLAND
# 20637      1007.0       433.0         1.7000          INLAND
# 20638       741.0       349.0         1.8672          INLAND
# 20639      1387.0       530.0         2.3886          INLAND
#
# [20433 rows x 9 columns]

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size= 0.2)

# %%
train_data = x_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 19729    -121.58     38.81                25.0        778.0           135.0
# 7094     -118.00     33.91                19.0       5166.0           770.0
# 4420     -118.26     34.07                46.0       2341.0           703.0
# 8029     -118.11     33.84                36.0       1463.0           257.0
# 11663    -118.02     33.85                31.0       1922.0           329.0
# ...          ...       ...                 ...          ...             ...
# 946      -121.92     37.72                 4.0       7477.0          1576.0
# 4793     -118.34     34.02                48.0       1614.0           320.0
# 6103     -117.88     34.11                18.0       2923.0           670.0
# 19884    -119.09     36.35                21.0       3146.0           595.0
# 9219     -120.27     37.12                36.0       1219.0           258.0
#
#        population  households  median_income ocean_proximity  \
# 19729       340.0       155.0         1.7857          INLAND
# 7094       2374.0       753.0         5.9790       <1H OCEAN
# 4420       2371.0       648.0         2.4038       <1H OCEAN
# 8029        722.0       260.0         4.8438       <1H OCEAN
# 11663      1030.0       353.0         5.3416       <1H OCEAN
# ...           ...         ...            ...             ...
# 946        2937.0      1506.0         5.1437       <1H OCEAN
# 4793        684.0       318.0         4.2218       <1H OCEAN
# 6103       1751.0       656.0         3.2383       <1H OCEAN
# 19884      1580.0       513.0         2.7857          INLAND
# 9219        639.0       245.0         1.9464          INLAND
#
#        median_house_value
# 19729            258300.0
# 7094             285200.0
# 4420             181700.0
# 8029             226300.0
# 11663            213000.0
# ...                   ...
# 946              299400.0
# 4793             181000.0
# 6103             157000.0
# 19884             92700.0
# 9219              57000.0
#
# [16346 rows x 10 columns]

# %%
train_data.hist(figsize=(15, 8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
print(train_data.dtypes)
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# ocean_proximity        object
# median_house_value    float64
# dtype: object

# %%
print(train_data.head())
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 13180    -117.74     33.97                 4.0       9755.0          1748.0
# 8061     -118.20     33.84                35.0       3405.0           779.0
# 16376    -121.29     38.03                 7.0       2021.0           441.0
# 1313     -121.79     38.00                36.0       1141.0           234.0
# 18123    -122.00     37.31                33.0       4211.0           918.0
#
#        population  households  median_income ocean_proximity  \
# 13180      4662.0      1583.0         5.6501       <1H OCEAN
# 8061       1953.0       671.0         2.7813      NEAR OCEAN
# 16376      1615.0       406.0         2.5842          INLAND
# 1313        562.0       213.0         2.5893          INLAND
# 18123      2389.0       861.0         4.7235       <1H OCEAN
#
#        median_house_value
# 13180            254900.0
# 8061             159200.0
# 16376            111300.0
# 1313             108500.0
# 18123            242200.0

# %%
train_data['total_rooms'] = np.log(train_data['total_rooms'] + 1)
train_data['total_bedrooms'] = np.log(train_data['total_bedrooms'] + 1)
train_data['population'] = np.log(train_data['population'] + 1)
train_data['households'] = np.log(train_data['households'] + 1)

# %%
train_data.hist(figsize=(15, 8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
 train_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7186
# INLAND        5233
# NEAR OCEAN    2115
# NEAR BAY      1807
# ISLAND           5
# Name: count, dtype: int64

# %%
pd.get_dummies(train_data.ocean_proximity)
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 19729      False    True   False     False       False
# 7094        True   False   False     False       False
# 4420        True   False   False     False       False
# 8029        True   False   False     False       False
# 11663       True   False   False     False       False
# ...          ...     ...     ...       ...         ...
# 946         True   False   False     False       False
# 4793        True   False   False     False       False
# 6103        True   False   False     False       False
# 19884      False    True   False     False       False
# 9219       False    True   False     False       False
#
# [16346 rows x 5 columns]

# %%
data = {'ocean_proximity': ['<1H OCEAN', 'INLAND', '<1H OCEAN', 'ISLAND']}
train_data = pd.DataFrame(data)

dummies = pd.get_dummies(train_data.ocean_proximity)
print(dummies)
# Out:
#    <1H OCEAN  INLAND  ISLAND
# 0       True   False   False
# 1      False    True   False
# 2       True   False   False
# 3      False   False    True

# %%
# Check data type
print(train_data['ocean_proximity'].dtype)

# Check unique values
print(train_data['ocean_proximity'].unique())

# Ensure it's categorical
train_data['ocean_proximity'] = train_data['ocean_proximity'].astype(str)

# Generate dummies
dummies = pd.get_dummies(train_data['ocean_proximity'])
print(dummies)
# Out:
# object
# ['<1H OCEAN' 'INLAND' 'ISLAND']
#    <1H OCEAN  INLAND  ISLAND
# 0       True   False   False
# 1      False    True   False
# 2       True   False   False
# 3      False   False    True

# %%
train_data
# Out:
#   ocean_proximity  <1H OCEAN  INLAND  ISLAND
# 0       <1H OCEAN          1       0       0
# 1          INLAND          0       1       0
# 2       <1H OCEAN          1       0       0
# 3          ISLAND          0       0       1

# %%
train_data = train_data.join(pd.get_dummies(train_data['ocean_proximity']).astype(int)).drop(['ocean_proximity'], axis=1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 19729    -121.58     38.81                25.0     6.658011        4.912655
# 7094     -118.00     33.91                19.0     8.550048        6.647688
# 4420     -118.26     34.07                46.0     7.758761        6.556778
# 8029     -118.11     33.84                36.0     7.288928        5.552960
# 11663    -118.02     33.85                31.0     7.561642        5.799093
# ...          ...       ...                 ...          ...             ...
# 946      -121.92     37.72                 4.0     8.919721        7.363280
# 4793     -118.34     34.02                48.0     7.387090        5.771441
# 6103     -117.88     34.11                18.0     7.980708        6.508769
# 19884    -119.09     36.35                21.0     8.054205        6.390241
# 9219     -120.27     37.12                36.0     7.106606        5.556828
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 19729    5.831882    5.049856         1.7857            258300.0          0
# 7094     7.772753    6.625392         5.9790            285200.0          1
# 4420     7.771489    6.475433         2.4038            181700.0          1
# 8029     6.583409    5.564520         4.8438            226300.0          1
# 11663    6.938284    5.869297         5.3416            213000.0          1
# ...           ...         ...            ...                 ...        ...
# 946      7.985484    7.317876         5.1437            299400.0          1
# 4793     6.529419    5.765191         4.2218            181000.0          1
# 6103     7.468513    6.487684         3.2383            157000.0          1
# 19884    7.365813    6.242223         2.7857             92700.0          0
# 9219     6.461468    5.505332         1.9464             57000.0          0
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 19729       1       0         0           0
# 7094        0       0         0           0
# 4420        0       0         0           0
# 8029        0       0         0           0
# 11663       0       0         0           0
# ...       ...     ...       ...         ...
# 946         0       0         0           0
# 4793        0       0         0           0
# 6103        0       0         0           0
# 19884       1       0         0           0
# 9219        1       0         0           0
#
# [16346 rows x 14 columns]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x="latitude", y="longitude", data=train_data, hue="median_house_value", palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_data['bedroom_ratio'] = train_data['total_bedrooms'] / train_data['total_rooms']
train_data['household_rooms'] = train_data['total_rooms'] / train_data['households']

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression
x_train, y_train = train_data.drop(['median_house_value'], axis=1), train_data['median_house_value']
reg = LinearRegression()
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
test_data = x_test.join(y_test)
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 13549    -117.31     34.13                36.0       1076.0           283.0
# 4602     -118.27     34.05                12.0        535.0           328.0
# 15632    -122.41     37.80                52.0       1394.0           395.0
# 13340    -117.67     34.02                16.0       3042.0           524.0
# 4561     -118.25     34.06                52.0        174.0            66.0
# ...          ...       ...                 ...          ...             ...
# 16356    -121.32     38.02                26.0       2851.0           533.0
# 11679    -117.99     33.84                34.0       2079.0           343.0
# 17607    -121.90     37.29                26.0       1797.0           244.0
# 8779     -118.32     33.80                39.0       1415.0           298.0
# 2376     -119.55     36.69                21.0       1551.0           423.0
#
#        population  households  median_income ocean_proximity  \
# 13549       773.0       224.0         2.6307          INLAND
# 4602       1194.0       365.0         1.2012       <1H OCEAN
# 15632      1700.0       400.0         2.7500        NEAR BAY
# 13340      1516.0       475.0         4.8906          INLAND
# 4561        249.0        57.0         1.7763       <1H OCEAN
# ...           ...         ...            ...             ...
# 16356      1544.0       499.0         3.5379          INLAND
# 11679      1379.0       352.0         5.1030       <1H OCEAN
# 17607       626.0       244.0         7.8575       <1H OCEAN
# 8779        729.0       278.0         3.1648       <1H OCEAN
# 2376       1519.0       406.0         1.7132          INLAND
#
#        median_house_value
# 13549             66400.0
# 4602             275000.0
# 15632            168800.0
# 13340            178500.0
# 4561             312500.0
# ...                   ...
# 16356             99100.0
# 11679            207000.0
# 17607            424600.0
# 8779             244800.0
# 2376              55900.0
#
# [4087 rows x 10 columns]

# %%
test_data['total_rooms'] = np.log(test_data['total_rooms'] + 1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms'] + 1)
test_data['population'] = np.log(test_data['population'] + 1)
test_data['households'] = np.log(test_data['households'] + 1)

test_data = test_data.join(pd.get_dummies(test_data.ocean_proximity)).astype(int).drop(['ocean_proximity'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11220\4183755912.py in ?()
#       2 test_data['total_bedrooms'] = np.log(test_data['total_bedrooms'] + 1)
#       3 test_data['population'] = np.log(test_data['population'] + 1)
#       4 test_data['households'] = np.log(test_data['households'] + 1)
#       5
# ----> 6 test_data = test_data.join(pd.get_dummies(test_data.ocean_proximity)).astype(int).drop(['ocean_proximity'], axis=1)
#       7
#       8 test_data['bedroom_ratio'] = test_data['total_bedrooms'] / test_data['total_rooms']
#       9 test_data['household_rooms'] = test_data['total_rooms'] / test_data['households']
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'ocean_proximity'

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 13549    -117.31     34.13                36.0     6.981935        5.648974
# 4602     -118.27     34.05                12.0     6.284134        5.796058
# 15632    -122.41     37.80                52.0     7.240650        5.981414
# 13340    -117.67     34.02                16.0     8.020599        6.263398
# 4561     -118.25     34.06                52.0     5.164786        4.204693
# ...          ...       ...                 ...          ...             ...
# 16356    -121.32     38.02                26.0     7.955776        6.280396
# 11679    -117.99     33.84                34.0     7.640123        5.840642
# 17607    -121.90     37.29                26.0     7.494430        5.501258
# 8779     -118.32     33.80                39.0     7.255591        5.700444
# 2376     -119.55     36.69                21.0     7.347300        6.049733
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 13549    6.651572    5.416100         2.6307             66400.0          0
# 4602     7.085901    5.902633         1.2012            275000.0          1
# 15632    7.438972    5.993961         2.7500            168800.0          0
# 13340    7.324490    6.165418         4.8906            178500.0          0
# 4561     5.521461    4.060443         1.7763            312500.0          1
# ...           ...         ...            ...                 ...        ...
# 16356    7.342779    6.214608         3.5379             99100.0          0
# 11679    7.229839    5.866468         5.1030            207000.0          1
# 17607    6.440947    5.501258         7.8575            424600.0          1
# 8779     6.593045    5.631212         3.1648            244800.0          1
# 2376     7.326466    6.008813         1.7132             55900.0          0
#
#        INLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 13549       1         0           0            NaN              NaN
# 4602        0         0           0            NaN              NaN
# 15632       0         1           0            NaN              NaN
# 13340       1         0           0            NaN              NaN
# 4561        0         0           0            NaN              NaN
# ...       ...       ...         ...            ...              ...
# 16356       1         0           0            NaN              NaN
# 11679       0         0           0            NaN              NaN
# 17607       0         0           0            NaN              NaN
# 8779        0         0           0            NaN              NaN
# 2376        1         0           0            NaN              NaN
#
# [4087 rows x 15 columns]

# %%
test_data['bedroom_ratio'] = test_data['total_bedrooms'] / test_data['total_rooms']
test_data['household_rooms'] = test_data['total_rooms'] / test_data['households']

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 13549    -117.31     34.13                36.0     1.124014        1.062799
# 4602     -118.27     34.05                12.0     1.093834        1.070330
# 15632    -122.41     37.80                52.0     1.134327        1.079515
# 13340    -117.67     34.02                16.0     1.162998        1.092878
# 4561     -118.25     34.06                52.0     1.036330        0.974394
# ...          ...       ...                 ...          ...             ...
# 16356    -121.32     38.02                26.0     1.160741        1.093662
# 11679    -117.99     33.84                34.0     1.149437        1.072570
# 17607    -121.90     37.29                26.0     1.144035        1.055007
# 8779     -118.32     33.80                39.0     1.134909        1.065460
# 2376     -119.55     36.69                21.0     1.138454        1.082818
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
#
is=1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 19729    -121.58     38.81                25.0     6.658011        4.912655
# 7094     -118.00     33.91                19.0     8.550048        6.647688
# 4420     -118.26     34.07                46.0     7.758761        6.556778
# 8029     -118.11     33.84                36.0     7.288928        5.552960
# 11663    -118.02     33.85                31.0     7.561642        5.799093
# ...          ...       ...                 ...          ...             ...
# 946      -121.92     37.72                 4.0     8.919721        7.363280
# 4793     -118.34     34.02                48.0     7.387090        5.771441
# 6103     -117.88     34.11                18.0     7.980708        6.508769
# 19884    -119.09     36.35                21.0     8.054205        6.390241
# 9219     -120.27     37.12                36.0     7.106606        5.556828
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 19729    5.831882    5.049856         1.7857            258300.0          0
# 7094     7.772753    6.625392         5.9790            285200.0          1
# 4420     7.771489    6.475433         2.4038            181700.0          1
# 8029     6.583409    5.564520         4.8438            226300.0          1
# 11663    6.938284    5.869297         5.3416            213000.0          1
# ...           ...         ...            ...                 ...        ...
# 946      7.985484    7.317876         5.1437            299400.0          1
# 4793     6.529419    5.765191         4.2218            181000.0          1
# 6103     7.468513    6.487684         3.2383            157000.0          1
# 19884    7.365813    6.242223         2.7857             92700.0          0
# 9219     6.461468    5.505332         1.9464             57000.0          0
#
#        INLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 19729       1         0           0       0.737856         1.318456
# 7094        0         0           0       0.777503         1.290497
# 4420        0         0           0       0.845081         1.198184
# 8029        0         0           0       0.761835         1.309893
# 11663       0         0           0       0.766909         1.288339
# ...       ...       ...         ...            ...              ...
# 946         0         0           0       0.825506         1.218895
# 4793        0         0           0       0.781287         1.281326
# 6103        0         0           0       0.815563         1.230132
# 19884       1         0           0       0.793404         1.290278
# 9219        1         0           0       0.781924         1.290859
#
# [16346 rows x 15 columns]

# %%
x_test, y_test = test_data.drop(['median_house_value'], axis=1), test_data['median_house_value']

# %%
reg.score(x_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 reg.score(x_test, y_test)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:848, in RegressorMixin.score(self, X, y, sample_weight)
#     806 """Return the coefficient of determination of the prediction.
#     807
#     808 The coefficient of determination :math:`R^2` is defined as
#    (...)
#     843 :class:`~sklearn.multioutput.MultiOutputRegressor`).
#     844 """
#     846 from .metrics import r2_score
# --> 848 y_pred = self.predict(X)
#     849 return r2_score(y, y_pred, sample_weight=sample_weight)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_base.py:306, in LinearModel.predict(self, X)
#     292 def predict(self, X):
#     293     """
#     294     Predict using the linear model.
#     295
#    (...)
#     304         Returns predicted values.
#     305     """
# --> 306     return self._decision_function(X)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_base.py:285, in LinearModel._decision_function(self, X)
#     282 def _decision_function(self, X):
#     283     check_is_fitted(self)
# --> 285     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     286     coef_ = self.coef_
#     287     if coef_.ndim == 1:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:608, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     537 def _validate_data(
#     538     self,
#     539     X="no_validation",
#    (...)
#     544     **check_params,
#     545 ):
#     546     """Validate input data and set or check the `n_features_in_` attribute.
#     547
#     548     Parameters
#    (...)
#     606         validated.
#     607     """
# --> 608     self._check_feature_names(X, reset=reset)
#     610     if y is None and self._get_tags()["requires_y"]:
#     611         raise ValueError(
#     612             f"This {self.__class__.__name__} estimator "
#     613             "requires y to be passed, but the target y is None."
#     614         )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:535, in BaseEstimator._check_feature_names(self, X, reset)
#     530 if not missing_names and not unexpected_names:
#     531     message += (
#     532         "Feature names must be in the same order as they were in fit.\n"
#     533     )
# --> 535 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names seen at fit time, yet now missing:
# - ISLAND

# %%
x_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 
_train)
# Out:
# LinearRegression()

# %%
reg.score(x_test, y_test)
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# -2239.2563607932884

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train_s = scaler.fit_transform(x_train)

# %%
x_test_s = scaler.fit_transform(x_test)

# %%
reg.score(x_test_s, y_test)
# Out:
# 0.6517089987204807

# %%
x_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 19729    -121.58     38.81                25.0     6.658011        4.912655
# 7094     -118.00     33.91                19.0     8.550048        6.647688
# 4420     -118.26     34.07                46.0     7.758761        6.556778
# 8029     -118.11     33.84                36.0     7.288928        5.552960
# 11663    -118.02     33.85                31.0     7.561642        5.799093
# ...          ...       ...                 ...          ...             ...
# 946      -121.92     37.72                 4.0     8.919721        7.363280
# 4793     -118.34     34.02                48.0     7.387090        5.771441
# 6103     -117.88     34.11                18.0     7.980708        6.508769
# 19884    -119.09     36.35                21.0     8.054205        6.390241
# 9219     -120.27     37.12                36.0     7.106606        5.556828
#
#        population  households  median_income  <1H OCEAN  INLAND  NEAR BAY  \
# 19729    5.831882    5.049856         1.7857          0       1         0
# 7094     7.772753    6.625392         5.9790          1       0         0
# 4420     7.771489    6.475433         2.4038          1       0         0
# 8029     6.583409    5.564520         4.8438          1       0         0
# 11663    6.938284    5.869297         5.3416          1       0         0
# ...           ...         ...            ...        ...     ...       ...
# 946      7.985484    7.317876         5.1437          1       0         0
# 4793     6.529419    5.765191         4.2218          1       0         0
# 6103     7.468513    6.487684         3.2383          1       0         0
# 19884    7.365813    6.242223         2.7857          0       1         0
# 9219     6.461468    5.505332         1.9464          0       1         0
#
#        NEAR OCEAN  bedroom_ratio  household_rooms
# 19729           0       0.737856         1.318456
# 7094            0       0.777503         1.290497
# 4420            0       0.845081         1.198184
# 8029            0       0.761835         1.309893
# 11663           0       0.766909         1.288339
# ...           ...            ...              ...
# 946             0       0.825506         1.218895
# 4793            0       0.781287         1.281326
# 6103            0       0.815563         1.230132
# 19884           0       0.793404         1.290278
# 9219            0       0.781924         1.290859
#
# [16346 rows x 14 columns]

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()

forest.fit(x_train_s, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(x_test_s, y_test)
# Out:
# 0.76680023591038

# %%
from sklearn.model_selection import GridSearchCV

# Define parameter grid
param_grid = {
    "n_estimators": [100, 200, 300],
    "min_samples_split": [2, 4],  # Corrected key
    "max_depth": [None, 4, 8]
}

# Initialize GridSearchCV
grid_search = GridSearchCV(
    forest,  # Ensure 'forest' is a properly initialized RandomForest model
    param_grid,
    cv=5,
    scoring="neg_mean_squared_error",
    return_train_score=True
)

# Fit the grid search
grid_search.fit(x_train_s, y_train)

# %%
best_forest = grid_search.best_estimator_

# %%
best_forest.score(x_test_s, y_test)

# %%
import sympy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import sympy
#
# ModuleNotFoundError: No module named 'sympy'

# %%
import numpy as np

# %%
import sympy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import sympy
#
# ModuleNotFoundError: No module named 'sympy'

# %%
# !pip install sympy
# Out:
# Collecting sympy
#   Downloading sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading sympy-1.13.3-py3-none-any.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    -------- ------------------------------- 1.3/6.2 MB 5.1 MB/s eta 0:00:01
#    -------------------- ------------------- 3.1/6.2 MB 7.1 MB/s eta 0:00:01
#    ------------------------------ --------- 4.7/6.2 MB 7.1 MB/s eta 0:00:01
#    -------------------------------------- - 6.0/6.2 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 6.8 MB/s eta 0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#    ---------------------------------------- 536.2/536.2 kB 8.6 MB/s eta 0:00:00
# Installing collected packages: mpmath, sympy
# Successfully installed mpmath-1.3.0 sympy-1.13.3

# %%
import sympy

# %%
j, w = sympy.symbols("j, w")

# %%
j = 1 / w#j= w**3 #j = w**2
j
# Out:
# 1/w

# %%
dj_dw = sympy.diff(j,w)

# %%
dj_dw
# Out:
# -1/w**2

# %%
dj_dw.subs([(w,2)])
# Out:
# -1/4
